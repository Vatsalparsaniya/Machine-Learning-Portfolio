# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x1 = [1,3,5,7,9]
y1 = [2,3,4,5,6]
x2 = [1,4,6,8,12,17]
y2 = [2,4,5,6,7,8]
plt.plot(x1,y1,label = "this is first")
plt.plot(x2,y2, label = "this is second")
plt.title("this is a first graph")
plt.legend()
plt.xlabel("this is X label")
plt.ylabel("this is y label")
plt.show()

# %%
plt.bar(x1,y1,label="this is Bar plot for first Dataset",color = 'g')
plt.bar(x2,y2,label="this is Bar plot for second Data-set",color='r')
plt.title("this is bar plot")
plt.xlabel("this is X label")
plt.ylabel("this is y label")
plt.legend()
plt.show()

# %%
population_ages = [22,55,62,45,21,22,34,42,42,4,99,102,110,120,121,122,130,111,115,112,80,75,65,54,44,43,42,48]
plt.hist(population_ages,bins=15,rwidth = 1)
# Out:
# (array([1., 0., 3., 1., 6., 2., 2., 1., 1., 1., 0., 2., 3., 3., 2.]),
#  array([  4. ,  12.4,  20.8,  29.2,  37.6,  46. ,  54.4,  62.8,  71.2,
#          79.6,  88. ,  96.4, 104.8, 113.2, 121.6, 130. ]),
#  <a list of 15 Patch objects>)

# %%
plt.scatter(x1,y1,label="this is first data set",color='g',s=25,marker="o")
plt.scatter(x2,y2,label="this is second data set",color='r',s=25,marker="*")

# %%
days = [1,2,3,4,5]
sleeping = [7,8,6,11,5]
eating =   [2,3,4,3,0]
working =  [7,8,7,2,0]
playing =  [8,5,7,8,0]
plt.stackplot(days, sleeping,eating,working,playing, colors=['m','c','r','k'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.show()

# %%
y2 = [10,11 ,13,16,20]
plt.stackplot(x1,y1,y2,colors=['r','g'])
plt.plot([],[],label="this is how we can apply label",color='b')
plt.title("this is stackplot")
plt.xlabel("here X values")
plt.ylabel("here y values")
plt.legend()
plt.show()

# %%
slices = [84,96,94,90]
activities = ["sem1","sem2","sem3","sem4"]
plt.pie(slices,labels=activities,explode=(.1,.1,.1,.1),shadow = True,startangle = 20,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x15db87f0>,
# ...
#  [Text(0.5718824602266107, 1.0549646684534792, 'sem1'),
#   Text(-1.0449364745213043, 0.5900065798065199, 'sem2'),
#   Text(-0.5165092946249917, -1.0831519508203795, 'sem3'),
#   Text(1.0919058914670379, -0.4977364002959534, 'sem4')],
#  [Text(0.33359810179885624, 0.6153960565978628, '23.1%'),
#   Text(-0.6095462768040942, 0.3441705048871366, '26.4%'),
#   Text(-0.30129708853124515, -0.6318386379785546, '25.8%'),
#   Text(0.636945103355772, -0.2903462335059728, '24.7%')])

# %%
# this is methods for subplots
#1
figure , ax = plt.subplots(nrows = 2, ncols = 2)

for row in ax:
    for col in row:
        col.plot(x1,y1)
plt.show()

# %%
#2
fig = plt.figure()

plt.subplot(2,2,1)
plt.title("first one")
plt.plot(x1,y1,color='b',label ="this is first graph")
plt.legend()
plt.subplot(2,2,2)
plt.title("Second one")
plt.plot(y2,y2,color='y',label="this is  second Graph")
plt.legend()
plt.subplot(2,2,3)
plt.title("third one")
plt.plot(x2,x2,color = 'g',label="this is third graph")
plt.legend()
plt.subplot(2,2,4)
plt.plot(y1,x1,color='r',label="this is forth graph")
plt.legend()
plt.title("forth one")
fig.tight_layout()
plt.show()

# %%
#3
fig,ax = plt.subplots(nrows=2,ncols=1)

ax[0].plot(x1,x1,'r')
ax[1].plot(x2,x2,'g')
plt.show()

# %%
name = ['sem1','sem2','sem3','sem4']
marks = [8.4,9.2,9,9.9]
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.bar(name,marks)
plt.subplot(132)
plt.scatter(name,marks)
plt.subplot(133)
plt.plot(name,marks)
plt.suptitle("this is quit intresting")
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
t3 = np.arange(0.0, 5.0, 0.07)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k' ,t3, f(t3), '--')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
def f(x):
    return np.cos(np.pi*x)

x = np.arange(0,1,0.01)
plt.figure(figsize=(15,15))
plt.subplot(211)
plt.hist(f(x),bins = x.size)
plt.xlabel("this is time")
plt.ylabel("this is cos(x)",fontsize=15,color='r')
plt.title("this is graph of cos function")
plt.text(-0.5,5,"hello......this is something new",fontsize=15,color='b')
plt.text(-0.5,4,"this is fun na...")
plt.grid(True)
plt.show()

# %%
data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())

# %%
plt.barh(group_names,group_data)
#plt.style.use('fivethirtyeight')
plt.show()

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));
plt.grid(False)
plt.show()

# %%
fig = plt.figure(facecolor='k', edgecolor='g')
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 5):
    ax = fig.add_subplot(2, 3, i)
fig.tight_layout()
plt.show()

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3,)
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()
